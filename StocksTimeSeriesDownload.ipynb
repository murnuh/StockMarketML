# %% [markdown]
# <a href="https://colab.research.google.com/github/murnuh/StockMarketML/blob/main/StocksTimeSeriesDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/murnuh/StockMarketML.git
# Out:
# Cloning into 'StockMarketML'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 29 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 474.77 KiB | 2.54 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !ls
# Out:
# "dd'"   sample_data   StockMarketML

# %%
import pandas as pd

df = pd.read_csv('/content/StockMarketML/sp500_companies.csv')

# %%
df.Symbol
# Out:
# 0       AAPL
# 1       MSFT
# 2       NVDA
# 3      GOOGL
# 4       GOOG
#        ...
# 498      IVZ
# 499      BWA
# 500      WBA
# 501     PARA
# 502     BBWI
# Name: Symbol, Length: 503, dtype: object

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
import yfinance as yf

# %matplotlib inline

# %%
# Now let's define a range, that means, from when until when we want the data:
start_date= dt.datetime(1995, 1, 1) # the format is YYYY-MM-DD
end_date= dt.datetime(2024, 6, 1)

# %%
stocks_timeseries = pd.DataFrame()
for x in df.Symbol:
  df1 = yf.Ticker(x.strip()).history(start = start_date,end = end_date)
  stocks_timeseries = pd.concat([stocks_timeseries, df1.rename(columns = {'Open':x})[x]], axis = 1)
# Out:
# ERROR:yfinance:$SW: possibly delisted; no price data found  (1d 1995-01-01 00:00:00 -> 2024-06-01 00:00:00) (Yahoo error = "Data doesn't exist for startDate = 788936400, endDate = 1717214400")

# %%
stocks_timeseries.tail(5)
# Out:
#                                  AAPL        MSFT        NVDA       GOOGL  \
# 2024-05-24 00:00:00-04:00  188.601698  426.421420  104.431483  174.547785
# 2024-05-28 00:00:00-04:00  191.288587  428.857015  110.225520  174.019099
# 2024-05-29 00:00:00-04:00  189.390786  424.924108  113.031052  174.996675
# 2024-05-30 00:00:00-04:00  190.539446  423.536599  114.630774  174.767255
# 2024-05-31 00:00:00-04:00  191.218664  416.000198  112.501133  171.435495
#
#                                  GOOG        AMZN        META       BRK-B  \
# 2024-05-24 00:00:00-04:00  176.087562  181.649994  466.710944  406.899994
# 2024-05-28 00:00:00-04:00  175.309480  179.929993  475.653527  408.239990
# 2024-05-29 00:00:00-04:00  176.376842  181.699997  473.737271  403.000000
# 2024-05-30 00:00:00-04:00  176.257148  181.309998  470.753073  403.769989
# 2024-05-31 00:00:00-04:00  172.975188  178.300003  464.894489  408.089996
#
# ...

# %%
stocks_timeseries.to_csv('stocksTimeSeries.csv')
